# %%
# LangChain core + community tools
pip install langchain langchain-community

# Google Gemini integration
pip install langchain-google-genai google-generativeai

# Environment variables support
pip install python-dotenv

# Requests library (API calls ke liye)
pip install requests

# Certifi (SSL certificates ke liye)
pip install certifi

# Streamlit (agar tum Streamlit app bana rahe ho)
pip install streamlit
# Out:
# Running cells with 'venv (3.10.11) (Python 3.10.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/dell/muliti-agent ai/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
import os 
import certifi 
from dotenv import load_dotenv
 langchain_google_genai import ChatGoogleGenerativeAI
from langchain.tools import tool
from langchain_community.tools.tavily_search import TavilySearchResults
from langchain import hub
from langchain.tools import tool
import requests
